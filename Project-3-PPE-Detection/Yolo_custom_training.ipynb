# %%
# !nvidia-smi
# Out:
# Thu Sep 26 04:53:39 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="5WpO1jiRPs91BevzwtOl")
project = rf.workspace("nida-fbg7w").project("construction-mbihh")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.
# ...
# Extracting Dataset Version Zip to construction-1 in yolov8:: 100%|██████████| 2140/2140 [00:00<00:00, 3640.24it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 874.1/874.1 kB 22.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo detect mode=predict model=yolov8l.pt conf=0.25 source=/content/construction-1/train/images
# Out:
# Ultralytics YOLOv8.2.101 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l summary (fused): 268 layers, 43,668,288 parameters, 0 gradients, 165.2 GFLOPs
#
# image 1/743 /content/construction-1/train/images/00011_jpg.rf.7e979e4dd6baaa4ba5973a9773eb0752.jpg: 640x640 2 persons, 63.0ms
# image 2/743 /content/construction-1/train/images/00014_jpg.rf.dcb96819277232406a259d2f1f56fadc.jpg: 640x640 2 persons, 46.5ms
# image 3/743 /content/construction-1/train/images/00035_jpg.rf.2f966172c054e813c7390ce10728d1b2.jpg: 640x640 1 person, 46.6ms
# image 4/743 /content/construction-1/train/images/00041_jpg.rf.303be5458ee840f482c5b996ba9fdc2c.jpg: 640x640 3 persons, 1 backpack, 1 potted plant, 46.6ms
# image 5/743 /content/construction-1/train/images/00060_jpg.rf.af2c0538c8602d75953ee7751ccbc8ce.jpg: 640x640 9 persons, 34.6ms
# image 6/743 /content/construction-1/train/images/00085_jpg.rf.92988658f3b9fa2df35ce0858756e568.jpg: 640x640 1 person, 33.0ms
# ...

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=/content/construction-1/data.yaml epochs=50
# Out:
# Ultralytics YOLOv8.2.101 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
